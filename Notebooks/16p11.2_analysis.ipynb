# %%
# Imports
import os
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import FileLink

# %%
# Directory
root_dir = "/Users/emmanuelle.coutu-nadeau/Library/Mobile Documents/com~apple~CloudDocs/UdeM/MSc Psycho/LABO NED - Personal Drive/Code/GENiAL/"
data_dir = os.path.join(root_dir, 'Data/Genetics/16p11.2/')

# %%
# Import both CSV files
brain_can_df = pd.read_csv(os.path.join(data_dir, 'Brain Canada - 16p11.2 demographics, IQ, dx.csv'), delimiter=';')
