# %% [markdown]
# 1. Import data
# 2. Merge data together
# 3. Clean and give demog report

# %% [markdown]
# # Imports

# %%
from Scripts.prepare_cnv_inputs_for_tool import prepare_cnv_inputs
from Scripts.data_processing_pipeline import *  # imports all defined pipeline steps

# %% [markdown]
# # Prepare CNV files for online tool

# %%
# Define file paths for CNV input preparation
genetics_only_data = 'Data/Genetics/Input/CNV-Analysis.csv'
hg38_output = 'Data/Genetics/Input/CNV-Analysis-Hg38.tsv'
hg19_output = 'Data/Genetics/Input/CNV-Analysis-Hg19.tsv'
hg18_output = 'Data/Genetics/Input/CNV-Analysis-Hg18.tsv'

# %%
# Run this only to prepare CNV input files for external tool
prepare_cnv_inputs(genetics_only_data, hg38_output, hg19_output, hg18_output)

# Calculated CNVs in hg38_output, hg19_output, and hg18_output variables

# %% [markdown]
# # Preprocessing

# %%
# Run this step
import_raw_data()

# %%
# Run this step
clean_and_merge_data()

# %%
# Run this step
standardize_variables()

# %%
# Run this step
remove_outliers()

# %%
# Run this step
add_additional_features()

# %%
# Run this step
finalize_and_export()
